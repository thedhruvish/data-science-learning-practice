# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('raw_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   iso_code                 50418 non-null  object
#  1   location                 50418 non-null  object
#  2   date                     50418 non-null  object
#  3   total_cases              47324 non-null  float64
#  4   total_deaths             39228 non-null  float64
#  5   stringency_index         43292 non-null  float64
#  6   population               50418 non-null  int64
#  7   gdp_per_capita           44706 non-null  float64
#  8   human_development_index  44216 non-null  float64
#  9   Unnamed: 9               50418 non-null  object
#  10  Unnamed: 10              50418 non-null  object
#  11  Unnamed: 11              50418 non-null  object
#  12  Unnamed: 12              50418 non-null  float64
#  13  Unnamed: 13              50418 non-null  object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 5.4+ MB

# %%
df['total_cases'].isnull().sum()
# Out:
# np.int64(3094)

# %%
df['total_cases'].mean()
# Out:
# np.float64(66219.27470205392)

# %%
df['total_cases'].median()
# Out:
# np.float64(1594.0)

# %%
# Out:
# <BarContainer object of 50418 artists>

# %%
sns.scatterplot(x=df['population'],y=df['total_cases'])
plt.show()

# %%
df['population'].value_counts()
# Out:
# population
# 38928341    294
# 43851043    294
# 1701583     294
# 2963234     294
# 9006400     294
#            ...
# 9537642     172
# 869595      171
# 2142252     158
# 7496988      51
# 686878        4
# Name: count, Length: 210, dtype: int64

# %%
df['location'].value_counts()
# Out:
# location
# Afghanistan        294
# Algeria            294
# Bahrain            294
# Armenia            294
# Austria            294
#                   ...
# Tajikistan         172
# Comoros            171
# Lesotho            158
# Hong Kong           51
# Solomon Islands      4
# Name: count, Length: 210, dtype: int64

# %%
df['total_cases'].value_counts()
# Out:
# total_cases
# 1.0        641
# 3.0        512
# 0.0        500
# 13.0       441
# 11.0       412
#           ...
# 71803.0      1
# 72310.0      1
# 72662.0      1
# 73116.0      1
# 10708.0      1
# Name: count, Length: 19172, dtype: int64

# %%
# Out:
#       iso_code location date  total_cases  total_deaths  stringency_index  \
# 0          NaN      NaN  NaN          NaN           NaN               NaN
# 1          NaN      NaN  NaN          NaN           NaN               NaN
# 2          NaN      NaN  NaN          NaN           NaN               NaN
# 3          NaN      NaN  NaN          NaN           NaN               NaN
# 4          NaN      NaN  NaN          NaN           NaN               NaN
# ...        ...      ...  ...          ...           ...               ...
# 50413      NaN      NaN  NaN          NaN           NaN               NaN
# 50414      NaN      NaN  NaN          NaN           NaN               NaN
# 50415      NaN      NaN  NaN          NaN           NaN               NaN
# 50416      NaN      NaN  NaN          NaN           NaN               NaN
# 50417      NaN      NaN  NaN          NaN           NaN               NaN
#
#        population  gdp_per_capita  human_development_index Unnamed: 9  \
# 0             NaN             NaN                      NaN        NaN
# 1             NaN             NaN                      NaN        NaN
# 2             NaN             NaN                      NaN        NaN
# 3             NaN             NaN                      NaN        NaN
# 4             NaN             NaN                      NaN        NaN
# ...           ...             ...                      ...        ...
# 50413         NaN             NaN                      NaN        NaN
# 50414         NaN             NaN                      NaN        NaN
# 50415         NaN             NaN                      NaN        NaN
# 50416         NaN             NaN                      NaN        NaN
# 50417         NaN             NaN                      NaN        NaN
#
#       Unnamed: 10 Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0             NaN         NaN          NaN         NaN
# 1             NaN         NaN          NaN         NaN
# 2             NaN         NaN          NaN         NaN
# 3             NaN         NaN          NaN         NaN
# 4             NaN         NaN          NaN         NaN
# ...           ...         ...          ...         ...
# 50413         NaN         NaN          NaN         NaN
# 50414         NaN         NaN          NaN         NaN
# 50415         NaN         NaN          NaN         NaN
# 50416         NaN         NaN          NaN         NaN
# 50417         NaN         NaN          NaN         NaN
#
# [50418 rows x 14 columns]

# %%
# df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31518 entries, 0 to 50417
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   iso_code                 31518 non-null  object
#  1   location                 31518 non-null  object
#  2   date                     31518 non-null  object
#  3   total_cases              31518 non-null  float64
#  4   total_deaths             31518 non-null  float64
#  5   stringency_index         31518 non-null  float64
#  6   population               31518 non-null  int64
#  7   gdp_per_capita           31518 non-null  float64
#  8   human_development_index  31518 non-null  float64
#  9   Unnamed: 9               31518 non-null  object
#  10  Unnamed: 10              31518 non-null  object
#  11  Unnamed: 11              31518 non-null  object
#  12  Unnamed: 12              31518 non-null  float64
#  13  Unnamed: 13              31518 non-null  object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 3.6+ MB

# %%
50418 - 31518
# Out:
# 18900
