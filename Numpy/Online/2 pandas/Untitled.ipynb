# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'].isnull().count()
# Out:
# np.int64(891)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
577/314
# Out:
# 1.8375796178343948

# %%
df['Fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df['Fare'].max()
# Out:
# np.float64(512.3292)

# %%
df['Fare'].min()
# Out:
# np.float64(0.0)

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['Age'] = df.groupby('Pclass')['Age'].transform(lambda x : x.fillna(x.mean()))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Cabin'].dropna()
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
df = df.dropna(subset=['Cabin'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  204 non-null    int64
#  1   Survived     204 non-null    int64
#  2   Pclass       204 non-null    int64
#  3   Name         204 non-null    object
#  4   Sex          204 non-null    object
#  5   Age          204 non-null    float64
#  6   SibSp        204 non-null    int64
#  7   Parch        204 non-null    int64
#  8   Ticket       204 non-null    object
#  9   Fare         204 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     202 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 20.7+ KB

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 252          253         0       1
# 498          499         0       1
# 248          249         1       1
# 741          742         0       1
# 102          103         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 252                        Stead, Mr. William Thomas    male  62.0      0
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 248                    Beckwith, Mr. Richard Leonard    male  37.0      1
# 741                    Cavendish, Mr. Tyrell William    male  36.0      1
# 102                        White, Mr. Richard Frasar    male  21.0      0
#
#      Parch  Ticket      Fare    Cabin Embarked
# 252      0  113514   26.5500      C87        S
# 498      2  113781  151.5500  C22 C26        S
# 248      1   11751   52.5542      D35        S
# 741      0   19877   78.8500      C46        S
# 102      1   35281   77.2875      D26        S

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 1    176
# 2     16
# 3     12
# Name: count, dtype: int64

# %%
df[(df['Pclass'] == 3) & (df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 128          129         1       3
# 394          395         1       3
# 429          430         1       3
# 751          752         1       3
# 823          824         1       3
#
#                                                   Name     Sex       Age  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.00000
# 128                                  Peter, Miss. Anna  female  25.14062
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.00000
# 429                 Pickard, Mr. Berk (Berk Trembisky)    male  32.00000
# 751                                Moor, Master. Meier    male   6.00000
# 823                                 Moor, Mrs. (Beila)  female  27.00000
#
#      SibSp  Parch             Ticket     Fare  Cabin Embarked
# 10       1      1            PP 9549  16.7000     G6        S
# 128      1      1               2668  22.3583  F E69        C
# 394      0      2            PP 9549  16.7000     G6        S
# 429      0      0  SOTON/O.Q. 392078   8.0500    E10        S
# 751      0      1             392096  12.4750   E121        S
# 823      0      1             392096  12.4750   E121        S

# %%
df[(df['Sex'] == 'male') & (df['Age'] < 16)]
# Out:
#      PassengerId  Survived  Pclass                                 Name   Sex  \
# 183          184         1       2            Becker, Master. Richard F  male
# 193          194         1       2           Navratil, Master. Michel M  male
# 305          306         1       1       Allison, Master. Hudson Trevor  male
# 340          341         1       2       Navratil, Master. Edmond Roger  male
# 445          446         1       1            Dodge, Master. Washington  male
# 751          752         1       3                  Moor, Master. Meier  male
# 802          803         1       1  Carter, Master. William Thornton II  male
#
#        Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 183   1.00      2      1  230136   39.0000       F4        S
# 193   3.00      1      1  230080   26.0000       F2        S
# 305   0.92      1      2  113781  151.5500  C22 C26        S
# 340   2.00      1      1  230080   26.0000       F2        S
# 445   4.00      0      2   33638   81.8583      A34        S
# 751   6.00      0      1  392096   12.4750     E121        S
# 802  11.00      1      2  113760  120.0000  B96 B98        S

# %%
df[(df['Sex'] == 'male') & (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 62            63         0       1
# 102          103         0       1
# 118          119         0       1
# 124          125         0       1
# 139          140         0       1
# 224          225         1       1
# 245          246         0       1
# 262          263         0       1
# 305          306         1       1
# 332          333         0       1
# 377          378         0       1
# 390          391         1       1
# 438          439         0       1
# 445          446         1       1
# 453          454         1       1
# 484          485         1       1
# 505          506         0       1
# 527          528         0       1
# 544          545         0       1
# 550          551         1       1
# 587          588         1       1
# 645          646         1       1
# 659          660         0       1
# 679          680         1       1
# 681          682         1       1
# 698          699         0       1
# 737          738         1       1
# 741          742         0       1
# 789          790         0       1
# 802          803         1       1
#
#                                            Name   Sex        Age  SibSp  \
# 27               Fortune, Mr. Charles Alexander  male  19.000000      3
# 62                  Harris, Mr. Henry Birkhardt  male  45.000000      1
# 102                   White, Mr. Richard Frasar  male  21.000000      0
# 118                    Baxter, Mr. Quigg Edmond  male  24.000000      0
# 124                 White, Mr. Percival Wayland  male  54.000000      0
# 139                          Giglio, Mr. Victor  male  24.000000      0
# 224                Hoyt, Mr. Frederick Maxfield  male  38.000000      1
# 245                 Minahan, Dr. William Edward  male  44.000000      2
# 262                           Taussig, Mr. Emil  male  52.000000      1
# 305              Allison, Master. Hudson Trevor  male   0.920000      1
# 332                   Graham, Mr. George Edward  male  38.000000      0
# 377                   Widener, Mr. Harry Elkins  male  27.000000      0
# 390                  Carter, Mr. William Ernest  male  36.000000      1
# 438                           Fortune, Mr. Mark  male  64.000000      1
# 445                   Dodge, Master. Washington  male   4.000000      0
# 453                    Goldenberg, Mr. Samuel L  male  49.000000      1
# 484                     Bishop, Mr. Dickinson H  male  25.000000      1
# 505  Penasco y Castellana, Mr. Victor de Satode  male  18.000000      1
# 527                          Farthing, Mr. John  male  38.233441      0
# 544                  Douglas, Mr. Walter Donald  male  50.000000      1
# 550                 Thayer, Mr. John Borland Jr  male  17.000000      0
# 587            Frolicher-Stehli, Mr. Maxmillian  male  60.000000      1
# 645                   Harper, Mr. Henry Sleeper  male  48.000000      1
# 659                  Newell, Mr. Arthur Webster  male  58.000000      0
# 679          Cardeza, Mr. Thomas Drake Martinez  male  36.000000      0
# 681                          Hassab, Mr. Hammad  male  27.000000      0
# 698                    Thayer, Mr. John Borland  male  49.000000      1
# 737                      Lesurer, Mr. Gustave J  male  35.000000      0
# 741               Cavendish, Mr. Tyrell William  male  36.000000      1
# 789                    Guggenheim, Mr. Benjamin  male  46.000000      0
# 802         Carter, Master. William Thornton II  male  11.000000      1
#
#      Parch    Ticket      Fare        Cabin Embarked
# 27       2     19950  263.0000  C23 C25 C27        S
# 62       0     36973   83.4750          C83        S
# 102      1     35281   77.2875          D26        S
# 118      1  PC 17558  247.5208      B58 B60        C
# 124      1     35281   77.2875          D26        S
# 139      0  PC 17593   79.2000          B86        C
# 224      0     19943   90.0000          C93        S
# 245      0     19928   90.0000          C78        Q
# 262      1    110413   79.6500          E67        S
# 305      2    113781  151.5500      C22 C26        S
# 332      1  PC 17582  153.4625          C91        S
# 377      2    113503  211.5000          C82        C
# 390      2    113760  120.0000      B96 B98        S
# 438      4     19950  263.0000  C23 C25 C27        S
# 445      2     33638   81.8583          A34        S
# 453      0     17453   89.1042          C92        C
# 484      0     11967   91.0792          B49        C
# 505      0  PC 17758  108.9000          C65        C
# 527      0  PC 17483  221.7792          C95        S
# 544      0  PC 17761  106.4250          C86        C
# 550      2     17421  110.8833          C70        C
# 587      1     13567   79.2000          B41        C
# 645      0  PC 17572   76.7292          D33        C
# 659      2     35273  113.2750          D48        C
# 679      1  PC 17755  512.3292  B51 B53 B55        C
# 681      0  PC 17572   76.7292          D49        C
# 698      1     17421  110.8833          C68        C
# 737      0  PC 17755  512.3292         B101        C
# 741      0     19877   78.8500          C46        S
# 789      0  PC 17593   79.2000      B82 B84        C
# 802      2    113760  120.0000      B96 B98        S

# %%
df.sort_values(by='Age',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 96            97         0       1             Goldschmidt, Mr. George B
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 456          457         0       1             Millet, Mr. Francis Davis
# ..           ...       ...     ...                                   ...
# 297          298         0       1          Allison, Miss. Helen Loraine
# 205          206         0       3            Strom, Miss. Telma Matilda
# 340          341         1       2        Navratil, Master. Edmond Roger
# 183          184         1       2             Becker, Master. Richard F
# 305          306         1       1        Allison, Master. Hudson Trevor
#
#         Sex    Age  SibSp  Parch     Ticket      Fare    Cabin Embarked
# 630    male  80.00      0      0      27042   30.0000      A23        S
# 96     male  71.00      0      0   PC 17754   34.6542       A5        C
# 745    male  70.00      1      1  WE/P 5735   71.0000      B22        S
# 54     male  65.00      0      1     113509   61.9792      B30        C
# 456    male  65.00      0      0      13509   26.5500      E38        S
# ..      ...    ...    ...    ...        ...       ...      ...      ...
# 297  female   2.00      1      2     113781  151.5500  C22 C26        S
# 205  female   2.00      0      1     347054   10.4625       G6        S
# 340    male   2.00      1      1     230080   26.0000       F2        S
# 183    male   1.00      2      1     230136   39.0000       F4        S
# 305    male   0.92      1      2     113781  151.5500  C22 C26        S
#
# [204 rows x 12 columns]

# %%
df['FareRank'] = df.groupby('Pclass')['Fare'].rank(ascending=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5956\3821644832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FareRank'] = df.groupby('Pclass')['Fare'].rank(ascending=False)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 1             2.0       1.0     1.0
# 3             4.0       1.0     1.0
# 6             7.0       0.0     1.0
# 10           11.0       1.0     3.0
# 11           12.0       1.0     1.0
# ...           ...       ...     ...
# 872         873.0       0.0     1.0
# 879         880.0       1.0     1.0
# 887         888.0       1.0     1.0
# 889         890.0       1.0     1.0
# rank          NaN       NaN     NaN
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 6                               McCarthy, Mr. Timothy J    male  54.0    0.0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0    1.0
# 11                             Bonnell, Miss. Elizabeth  female  58.0    0.0
# ...                                                 ...     ...   ...    ...
# 872                            Carlsson, Mr. Frans Olof    male  33.0    0.0
# 879       Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0    0.0
# 887                        Graham, Miss. Margaret Edith  female  19.0    0.0
# 889                               Behr, Mr. Karl Howell    male  26.0    0.0
# rank                                                NaN     NaN   NaN    NaN
#
#       Parch    Ticket     Fare        Cabin Embarked  FareRank   rank
# 1       0.0  PC 17599  71.2833          C85        C      84.0   84.0
# 3       0.0    113803  53.1000         C123        S     107.0  107.0
# 6       0.0     17463  51.8625          E46        S     118.5  118.5
# 10      1.0   PP 9549  16.7000           G6        S       2.5    2.5
# 11      0.0    113783  26.5500         C103        S     159.5  159.5
# ...     ...       ...      ...          ...      ...       ...    ...
# 872     0.0       695   5.0000  B51 B53 B55        S     173.0  173.0
# 879     1.0     11767  83.1583          C50        C      60.0   60.0
# 887     0.0    112053  30.0000          B42        S     146.0  146.0
# 889     0.0    111369  30.0000         C148        C     146.0  146.0
# rank    NaN       NaN      NaN          NaN      NaN       NaN    NaN
#
# [205 rows x 14 columns]

# %%
df.groupby(['Pclass','Sex'])['Survived'].mean()
# Out:
# Pclass  Sex
# 1.0     female    0.962963
#         male      0.410526
# 2.0     female    0.900000
#         male      0.666667
# 3.0     female    0.666667
#         male      0.333333
# Name: Survived, dtype: float64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    129
# C     69
# Q      4
# Name: count, dtype: int64

# %%
df.groupby('Embarked')[['Fare','Age']].mean()
# Out:
#                 Fare        Age
# Embarked
# C         101.520957  37.316535
# Q          50.025000  33.004562
# S          63.316440  34.988021

# %%
df['AgeGroup'] = pd.cut(df['Age'],bins=[0,18,60,100],labels=['Child','Adult','Senior'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5956\4048613418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AgeGroup'] = pd.cut(df['Age'],bins=[0,18,60,100],labels=['Child','Adult','Senior'])

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 1             2.0       1.0     1.0
# 3             4.0       1.0     1.0
# 6             7.0       0.0     1.0
# 10           11.0       1.0     3.0
# 11           12.0       1.0     1.0
# ...           ...       ...     ...
# 872         873.0       0.0     1.0
# 879         880.0       1.0     1.0
# 887         888.0       1.0     1.0
# 889         890.0       1.0     1.0
# rank          NaN       NaN     NaN
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 6                               McCarthy, Mr. Timothy J    male  54.0    0.0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0    1.0
# 11                             Bonnell, Miss. Elizabeth  female  58.0    0.0
# ...                                                 ...     ...   ...    ...
# 872                            Carlsson, Mr. Frans Olof    male  33.0    0.0
# 879       Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0    0.0
# 887                        Graham, Miss. Margaret Edith  female  19.0    0.0
# 889                               Behr, Mr. Karl Howell    male  26.0    0.0
# rank                                                NaN     NaN   NaN    NaN
#
#       Parch    Ticket     Fare        Cabin Embarked  FareRank   rank AgeGroup
# 1       0.0  PC 17599  71.2833          C85        C      84.0   84.0    Adult
# 3       0.0    113803  53.1000         C123        S     107.0  107.0    Adult
# 6       0.0     17463  51.8625          E46        S     118.5  118.5    Adult
# 10      1.0   PP 9549  16.7000           G6        S       2.5    2.5    Child
# 11      0.0    113783  26.5500         C103        S     159.5  159.5    Adult
# ...     ...       ...      ...          ...      ...       ...    ...      ...
# 872     0.0       695   5.0000  B51 B53 B55        S     173.0  173.0    Adult
# 879     1.0     11767  83.1583          C50        C      60.0   60.0    Adult
# 887     0.0    112053  30.0000          B42        S     146.0  146.0    Adult
# 889     0.0    111369  30.0000         C148        C     146.0  146.0    Adult
# rank    NaN       NaN      NaN          NaN      NaN       NaN    NaN      NaN
#
# [205 rows x 15 columns]

# %%
df['FarePerPerson'] = df['Fare'] /(df['SibSp'] + df['Pclass'] +1 )
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5956\1441819293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FarePerPerson'] = df['Fare'] /(df['SibSp'] + df['Pclass'] +1 )

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 1             2.0       1.0     1.0
# 3             4.0       1.0     1.0
# 6             7.0       0.0     1.0
# 10           11.0       1.0     3.0
# 11           12.0       1.0     1.0
# ...           ...       ...     ...
# 872         873.0       0.0     1.0
# 879         880.0       1.0     1.0
# 887         888.0       1.0     1.0
# 889         890.0       1.0     1.0
# rank          NaN       NaN     NaN
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 6                               McCarthy, Mr. Timothy J    male  54.0    0.0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0    1.0
# 11                             Bonnell, Miss. Elizabeth  female  58.0    0.0
# ...                                                 ...     ...   ...    ...
# 872                            Carlsson, Mr. Frans Olof    male  33.0    0.0
# 879       Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0    0.0
# 887                        Graham, Miss. Margaret Edith  female  19.0    0.0
# 889                               Behr, Mr. Karl Howell    male  26.0    0.0
# rank                                                NaN     NaN   NaN    NaN
#
#       Parch    Ticket     Fare        Cabin Embarked  FareRank   rank  \
# 1       0.0  PC 17599  71.2833          C85        C      84.0   84.0
# 3       0.0    113803  53.1000         C123        S     107.0  107.0
# 6       0.0     17463  51.8625          E46        S     118.5  118.5
# 10      1.0   PP 9549  16.7000           G6        S       2.5    2.5
# 11      0.0    113783  26.5500         C103        S     159.5  159.5
# ...     ...       ...      ...          ...      ...       ...    ...
# 872     0.0       695   5.0000  B51 B53 B55        S     173.0  173.0
# 879     1.0     11767  83.1583          C50        C      60.0   60.0
# 887     0.0    112053  30.0000          B42        S     146.0  146.0
# 889     0.0    111369  30.0000         C148        C     146.0  146.0
# rank    NaN       NaN      NaN          NaN      NaN       NaN    NaN
#
#      AgeGroup  FarePerPerson
# 1       Adult       23.76110
# 3       Adult       17.70000
# 6       Adult       25.93125
# 10      Child        3.34000
# 11      Adult       13.27500
# ...       ...            ...
# 872     Adult        2.50000
# 879     Adult       41.57915
# 887     Adult       15.00000
# 889     Adult       15.00000
# rank      NaN            NaN
#
# [205 rows x 16 columns]

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x='day', y='tip_percentage')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 sns.boxplot(data=df, x='day', y='tip_percentage')
#
# File C:\Program Files\Python312\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
#    1603         legend=legend,
#    1604     )
#    1606     if ax is None:
#    1607         ax = plt.gca()
#
# File C:\Program Files\Python312\Lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File C:\Program Files\Python312\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File C:\Program Files\Python312\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File C:\Program Files\Python312\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File C:\Program Files\Python312\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `tip_percentage` for `y`. An entry with this name does not appear in `data`.
