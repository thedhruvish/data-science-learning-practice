# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.array([0,10]),np.array([0,29]))

# %%
plt.plot(np.array([0,2,10]),np.array([4,5,15]),'o')

# %%
plt.plot(np.array([2,4,6,80]),np.array([5,3,65,5]))

# %%
plt.plot(np.array([2,5,6,8,1]),'o-.b',)

# %%
plt.plot(np.array([2,5,6,8,1]),'o-.b',ms=15)

# %%
plt.plot(np.array([2,5,6,8,1]),marker='o',ms=15,mec ='#000')

# %%
plt.plot(np.array([2,5,6,8,1]),marker='o',ms=15,mfc ='#341548')

# %%
plt.plot(np.array([2,5,6,8,1]),marker='o',ms=15,mfc ='hotpink')

# %%
plt.plot(np.array([4,3,6,2]),linestyle='dotted')

# %%
plt.plot(np.array([4,3,6,2]),linestyle='dashed')

# %%
plt.plot(np.array([4,3,6,2]),ls = '--',c='red')

# %%
plt.plot(np.array([4,3,6,2]),ls = '--',c='red',linewidth=15)

# %%
plt.xlabel('Data X',fontdict={'family':'serif','color':'blue','size':20},loc='left')
plt.ylabel('Data Y')
plt.title('Demo')
plt.plot(np.array([3,5,3,2]))
plt.plot(np.array([6,3,6,3]))

plt.show()

# %%
plt.xlabel('Data X',fontdict={'family':'serif','color':'blue','size':20},loc='left')
plt.ylabel('Data Y')
plt.title('Demo')
plt.plot(np.array([3,5,3,2]))
plt.plot(np.array([6,3,6,3]))
plt.grid(axis='x')

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.linspace(0,50,15)
y = np.cos(x)
plt.scatter(x, y)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y,cmap='viridis')
# Out:
# C:\Users\c9\AppData\Local\Temp\ipykernel_8808\1384038163.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,cmap='viridis')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y, s=np.linspace(0,100,13))

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y, s=np.linspace(0,100,13),alpha=0.5)

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y,color='red')
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color='red',width=0.1)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
# Out:
# (array([ 1.,  1.,  1., 28., 44., 65., 57., 33., 15.,  5.]),
#  array([129.36671683, 136.43605313, 143.50538942, 150.57472572,
#         157.64406201, 164.71339831, 171.7827346 , 178.8520709 ,
#         185.92140719, 192.99074349, 200.06007978]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.randint(0,10,4)
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x238e5133750>,
# ...
#  [Text(0.6568744397048419, 0.882335520344982, ''),
#   Text(-0.6568744116584752, 0.8823355412247273, ''),
#   Text(-1.070349387579117, -0.2536773314843278, ''),
#   Text(0.5499999116781021, -0.9526279951555487, '')])

# %%
x = np.random.randint(0,10,4)
plt.pie(x,labels=[2,4,2,5])
# Out:
# ([<matplotlib.patches.Wedge at 0x238e4df8410>,
# ...
#  [Text(1.1, 0.0, '2'),
#   Text(1.0724206992662373, 0.24477304546316989, '4'),
#   Text(-0.24477317224173614, 1.0724206703298467, '2'),
#   Text(1.311736850028664e-08, -1.0999999999999999, '5')])

# %%
x = np.random.randint(0,10,4)
plt.pie(x,labels=[2,4,2,5],startangle=80)
# Out:
# ([<matplotlib.patches.Wedge at 0x238e5269090>,
# ...
#  [Text(-0.2979246654988637, 1.0588866292891748, '2'),
#   Text(-0.8931319205414263, 0.6421178805406244, '4'),
#   Text(-0.9660436475521135, -0.5260795291818608, '2'),
#   Text(1.0832885683736377, -0.1910127682407498, '5')])

# %%
x = np.random.randint(0,10,4)
plt.pie(x,labels=[2,4,2,5],explode=[0.2,0,0,0.10],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x238e4ff8910>,
# ...
#  [Text(1.0163808982209277, 0.8105367787655414, '2'),
#   Text(-0.991065822968052, 0.4772719712539778, '4'),
#   Text(-0.24477260120619015, -1.0724208006649047, '2'),
#   Text(0.9381977046393746, -0.7481878554276388, '5')])

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y)

plt.show()
